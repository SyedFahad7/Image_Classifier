# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten
from keras.models import load_model
from keras.preprocessing import image

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %%
img_width, img_height = 150, 150
def load_and_preprocess_data(data_dir):
    images = []
    labels = []

    for label, category in enumerate(['Cat', 'Dog']):
        category_dir = os.path.join(data_dir, category)
        for img_name in os.listdir(category_dir):
            img_path = os.path.join(category_dir, img_name)
            img = cv2.imread(img_path)
            if img is None:
                continue
            img = cv2.resize(img, (img_width, img_height))
            img = img / 255.0  # Normalize pixel values to range [0, 1]
            images.append(img)
            labels.append(label)

    return np.array(images), np.array(labels)

# %%
train_data_dir = r'C:\Users\Admin\Desktop\BharatIntern\Project 2\kagglecatsanddogs_3367a\Petimages'
train_images, train_labels = load_and_preprocess_data(train_data_dir)

# %%
print("Number of training images:", len(train_images))
print("Number of cat images:", np.sum(train_labels == 0))
print("Number of dog images:", np.sum(train_labels == 1))
# Out:
# Number of training images: 1996
# Number of cat images: 996
# Number of dog images: 1000

# %%
model = Sequential(name="my_cnn_model")
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(img_width, img_height, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))  # Binary classification, so using sigmoid activation

# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',  # Since it's a binary classification problem
              metrics=['accuracy'])

# Display the model summary
model.summary()
# Out:
# C:\Users\Admin\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Model: "my_cnn_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 148, 148, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 74, 74, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
# Train the model
history = model.fit(train_images, train_labels, epochs=10, batch_size=32, validation_split=0.2)

# Evaluate the model on the training data
train_loss, train_accuracy = model.evaluate(train_images, train_labels)

print("Training Loss:", train_loss)
print("Training Accuracy:", train_accuracy)

# Saving the model in the Keras format
model.save("my_cnn_model.keras")
print("Model saved as my_cnn_model.keras")
# Out:
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 109s 2s/step - accuracy: 0.5772 - loss: 0.7792 - val_accuracy: 0.0000e+00 - val_loss: 0.9312
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.6265 - loss: 0.6514 - val_accuracy: 0.0150 - val_loss: 1.2280
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.6723 - loss: 0.6161 - val_accuracy: 0.2650 - val_loss: 1.0639
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.7489 - loss: 0.5400 - val_accuracy: 0.3300 - val_loss: 1.0092
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7838 - loss: 0.4858 - val_accuracy: 0.3775 - val_loss: 1.2177
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.8087 - loss: 0.4015 - val_accuracy: 0.4200 - val_loss: 1.4797
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.8393 - loss: 0.3375 - val_accuracy: 0.5225 - val_loss: 1.4826
# Epoch 8/10
# ...

# %%
#Now we can test our model 
from keras.models import load_model
from keras.preprocessing import image
import numpy as np
import os
from tabulate import tabulate
from colorama import Fore, Style

# Load and preprocess the test data
test_images, test_labels = load_and_preprocess_data(test_dir)

# Initialize lists to store prediction results
predictions_table = []

# Loop through each image in the test directory
for class_name in class_names:
    class_dir = os.path.join(test_dir, class_name)
    for img_file in os.listdir(class_dir):
        img_path = os.path.join(class_dir, img_file)
        
        # Load and preprocess the image
        img = image.load_img(img_path, target_size=(img_width, img_height))  # Adjust target_size to match model's input size
        img_array = image.img_to_array(img)
        img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
        img_array /= 255.0  # Normalize pixel values
        
        # Make predictions without verbose output
        predictions = model.predict(img_array, verbose=0)
        predicted_class = class_names[int(np.round(predictions[0]))]  # Use int(np.round(predictions[0])) to get the predicted class index
        
        # Store prediction results
        predictions_table.append([predicted_class])

import matplotlib.pyplot as plt

def print_predictions(predictions_table):
    bold_border = f"{Style.BRIGHT + '-' * 42 + Style.RESET_ALL}"
    print(bold_border)
    print(tabulate([(Fore.GREEN + row[0],) for row in predictions_table], headers=[Fore.GREEN + "Predicted Class"], tablefmt="fancy_grid"))
    print(bold_border)

def evaluate_model(model, test_images, test_labels):
    test_loss, test_accuracy = model.evaluate(test_images, test_labels, verbose=0)
    print("Test Loss:", test_loss)
    print("Test Accuracy:", test_accuracy)

def plot_first_10_images_with_predictions(test_images, predicted_probabilities, class_names):
    plt.figure(figsize=(10, 10))
    for i in range(10):
        plt.subplot(5, 2, i + 1)
        plt.imshow(test_images[i])
        plt.title(f"Predicted: {class_names[np.argmax(predicted_probabilities[i])]}")
        plt.axis('off')
    plt.tight_layout()
    plt.show()

def plot_prediction_distribution(predicted_probabilities, class_names):
    plt.figure(figsize=(12, 6))

    # Subplot 1: Bar chart showing the distribution of predicted classes for the first image
    plt.subplot(1, 2, 1)
    plt.bar(class_names, predicted_probabilities[0])
    plt.title("Predicted Probabilities for First Image")
    plt.xlabel("Classes")
    plt.ylabel("Probability")

    # Subplot 2: Pie chart showing the distribution of predicted classes for the second image
    plt.subplot(1, 2, 2)
    predicted_probabilities_second_image = predicted_probabilities[1]
    if len(predicted_probabilities_second_image) == len(class_names):
        plt.pie(predicted_probabilities_second_image, labels=class_names, autopct='%1.1f%%')
        plt.title("Predicted Probabilities for Second Image")
    else:
        print("Lengths of predicted probabilities and class names do not match.")
    
    plt.tight_layout()
    plt.show()


# Print predictions
print_predictions(predictions_table)

# Evaluate the model
evaluate_model(model, test_images, test_labels)

# Get the predicted probabilities for each class for all test images
predicted_probabilities = model.predict(test_images)

# Plot first 10 images with predictions
plot_first_10_images_with_predictions(test_images, predicted_probabilities, class_names)

# Plot prediction distribution
plot_prediction_distribution(predicted_probabilities, class_names)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13332\2833278129.py:29: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   predicted_class = class_names[int(np.round(predictions[0]))]  # Use int(np.round(predictions[0])) to get the predicted class index
# ------------------------------------------
# ╒═══════════════════╕
# │ Predicted Class   │
# ╞═══════════════════╡
# │ Cat               │
# ├───────────────────┤
# │ Dog               │
# ├───────────────────┤
# │ Dog               │
# ├───────────────────┤
# │ Cat               │
# ├───────────────────┤
# │ Cat               │
# ├───────────────────┤
# │ Cat               │
# ├───────────────────┤
# │ Cat               │
# ├───────────────────┤
# │ Dog               │
# ├───────────────────┤
# │ Cat               │
# ├───────────────────┤
# │ Cat               │
# ...
